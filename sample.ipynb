# %%
pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing zipfile to unzip the File
import zipfile

# %%
#unzipping file
with zipfile.ZipFile("C:\\Users\\kaladevi\\sample\\-\\.kaggle\\orders.csv.zip","r") as file:
    file.extractall("orders")

# %%
#creating the file to csv by importing operating system(os)
import os
os.listdir("orders")
# Out:
# ['orders.csv']

# %%
#importing pandas to read csv file
import pandas as pd

# %%
#reading the csv file in dataframe
df=pd.read_csv("orders/orders.csv")
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
#info of dataframe to see the types of object
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Id          9994 non-null   int64
#  1   Order Date        9994 non-null   object
#  2   Ship Mode         9993 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub Category      9994 non-null   object
#  11  Product Id        9994 non-null   object
#  12  cost price        9994 non-null   int64
#  13  List Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount Percent  9994 non-null   int64
# dtypes: int64(6), object(10)
# ...

# %%
#to show the column names
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %%
# to see the number null values presnt in each columns
df.isna().sum()
# Out:
# Order Id            0
# Order Date          0
# Ship Mode           1
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# dtype: int64

# %%
# to fill the null values with 0
df.fillna({'Ship Mode':0},inplace=True)

# %%
#to see the changes made
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
# to check the correction
df.isna().sum()
# Out:
# Order Id            0
# Order Date          0
# Ship Mode           0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# dtype: int64

# %%
#to see number of rows and columns
df.shape
# Out:
# (9994, 16)

# %%
#to check the number of non nulls and data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Id          9994 non-null   int64
#  1   Order Date        9994 non-null   object
#  2   Ship Mode         9994 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub Category      9994 non-null   object
#  11  Product Id        9994 non-null   object
#  12  cost price        9994 non-null   int64
#  13  List Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount Percent  9994 non-null   int64
# dtypes: int64(6), object(10)
# ...

# %%
#to rename the column names
df.rename(columns={'Order Id':'ORDER_ID','Order Date':'ORDER_DATE','Ship Mode':'SHIP_MODE','Segment':'SEGMENT','Country':'COUNTRY','City':'CITY','State':'STATE','Postal Code':'POSTALl_CODE','Region':'REGION','Category':'CATEGORY','Sub Category':'SUB_CATEGORY','Product Id':'PRODUCT_ID','cost price':'COST_PRICE','List Price':'LIST_PRICE','Quantity':'QUANTITY','Discount Percent':'DISCOUNT_PERCENT'},inplace=True)

# %%
#after renaming the column names
df
# Out:
#       ORDER_ID  ORDER_DATE       SHIP_MODE    SEGMENT        COUNTRY  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  CITY       STATE  POSTALl_CODE REGION         CATEGORY  \
# ...

# %%
# column info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDER_ID          9994 non-null   int64
#  1   ORDER_DATE        9994 non-null   object
#  2   SHIP_MODE         9994 non-null   object
#  3   SEGMENT           9994 non-null   object
#  4   COUNTRY           9994 non-null   object
#  5   CITY              9994 non-null   object
#  6   STATE             9994 non-null   object
#  7   POSTALl_CODE      9994 non-null   int64
#  8   REGION            9994 non-null   object
#  9   CATEGORY          9994 non-null   object
#  10  SUB_CATEGORY      9994 non-null   object
#  11  PRODUCT_ID        9994 non-null   object
#  12  COST_PRICE        9994 non-null   int64
#  13  LIST_PRICE        9994 non-null   int64
#  14  QUANTITY          9994 non-null   int64
#  15  DISCOUNT_PERCENT  9994 non-null   int64
# dtypes: int64(6), object(10)
# ...

# %%
#to change the data type 
df['ORDER_DATE']=pd.to_datetime(df['ORDER_DATE'])

# %%
#seeing the data change
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDER_ID          9994 non-null   int64
#  1   ORDER_DATE        9994 non-null   datetime64[ns]
#  2   SHIP_MODE         9994 non-null   object
#  3   SEGMENT           9994 non-null   object
#  4   COUNTRY           9994 non-null   object
#  5   CITY              9994 non-null   object
#  6   STATE             9994 non-null   object
#  7   POSTALl_CODE      9994 non-null   int64
#  8   REGION            9994 non-null   object
#  9   CATEGORY          9994 non-null   object
#  10  SUB_CATEGORY      9994 non-null   object
#  11  PRODUCT_ID        9994 non-null   object
#  12  COST_PRICE        9994 non-null   int64
#  13  LIST_PRICE        9994 non-null   int64
#  14  QUANTITY          9994 non-null   int64
#  15  DISCOUNT_PERCENT  9994 non-null   int64
# ...

# %%
#changing the type of datas
df['SEGMENT']=df['SEGMENT'].str.rstrip()

# %%
#checking the type og "SEGMENT"set
type({"SEGMENT"})
# Out:
# set

# %%
df['COUNTRY']=df['COUNTRY'].str.rstrip()

# %%
type({"COUNTRY"})
# Out:
# set

# %%
df['CITY']=df['CITY'].str.rstrip()

# %%
df['STATE']=df['STATE'].str.rstrip()

# %%
df['REGION']=df['REGION'].str.rstrip()

# %%
df['CATEGORY']=df['CATEGORY'].str.rstrip()

# %%
df['SUB_CATEGORY']=df['SUB_CATEGORY'].str.rstrip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDER_ID          9994 non-null   int64
#  1   ORDER_DATE        9994 non-null   datetime64[ns]
#  2   SHIP_MODE         9994 non-null   object
#  3   SEGMENT           9994 non-null   object
#  4   COUNTRY           9994 non-null   object
#  5   CITY              9994 non-null   object
#  6   STATE             9994 non-null   object
#  7   POSTALl_CODE      9994 non-null   int64
#  8   REGION            9994 non-null   object
#  9   CATEGORY          9994 non-null   object
#  10  SUB_CATEGORY      9994 non-null   object
#  11  PRODUCT_ID        9994 non-null   object
#  12  COST_PRICE        9994 non-null   int64
#  13  LIST_PRICE        9994 non-null   int64
#  14  QUANTITY          9994 non-null   int64
#  15  DISCOUNT_PERCENT  9994 non-null   int64
# ...

# %%
df
# Out:
#       ORDER_ID ORDER_DATE       SHIP_MODE    SEGMENT        COUNTRY  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  CITY       STATE  POSTALl_CODE REGION         CATEGORY  \
# 0           Henderson    Kentucky         42420  South        Furniture
# ...

# %%
#calculating discount
df['DISCOUNT']=(df['LIST_PRICE']*df['DISCOUNT_PERCENT'])/100

# %%
#discount column
df['DISCOUNT']
# Out:
# 0        5.2
# 1       21.9
# 2        0.5
# 3       19.2
# 4        1.0
#         ...
# 9989     1.2
# 9990     3.6
# 9991     5.2
# 9992     0.9
# 9993     7.2
# Name: DISCOUNT, Length: 9994, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDER_ID          9994 non-null   int64
#  1   ORDER_DATE        9994 non-null   datetime64[ns]
#  2   SHIP_MODE         9994 non-null   object
#  3   SEGMENT           9994 non-null   object
#  4   COUNTRY           9994 non-null   object
#  5   CITY              9994 non-null   object
#  6   STATE             9994 non-null   object
#  7   POSTALl_CODE      9994 non-null   int64
#  8   REGION            9994 non-null   object
#  9   CATEGORY          9994 non-null   object
#  10  SUB_CATEGORY      9994 non-null   object
#  11  PRODUCT_ID        9994 non-null   object
#  12  COST_PRICE        9994 non-null   int64
#  13  LIST_PRICE        9994 non-null   int64
#  14  QUANTITY          9994 non-null   int64
#  15  DISCOUNT_PERCENT  9994 non-null   int64
# ...

# %%
df.fillna({'DISCOUNT':0},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDER_ID          9994 non-null   int64
#  1   ORDER_DATE        9994 non-null   datetime64[ns]
#  2   SHIP_MODE         9994 non-null   object
#  3   SEGMENT           9994 non-null   object
#  4   COUNTRY           9994 non-null   object
#  5   CITY              9994 non-null   object
#  6   STATE             9994 non-null   object
#  7   POSTALl_CODE      9994 non-null   int64
#  8   REGION            9994 non-null   object
#  9   CATEGORY          9994 non-null   object
#  10  SUB_CATEGORY      9994 non-null   object
#  11  PRODUCT_ID        9994 non-null   object
#  12  COST_PRICE        9994 non-null   int64
#  13  LIST_PRICE        9994 non-null   int64
#  14  QUANTITY          9994 non-null   int64
#  15  DISCOUNT_PERCENT  9994 non-null   int64
# ...

# %%
df
# Out:
#       ORDER_ID ORDER_DATE       SHIP_MODE    SEGMENT        COUNTRY  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  CITY       STATE  POSTALl_CODE REGION         CATEGORY  \
# 0           Henderson    Kentucky         42420  South        Furniture
# ...

# %%
#calculating profit
df['PROFIT']=df['LIST_PRICE']-df['COST_PRICE']

# %%
df
# Out:
#       ORDER_ID ORDER_DATE       SHIP_MODE    SEGMENT        COUNTRY  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  CITY       STATE  POSTALl_CODE REGION         CATEGORY  \
# 0           Henderson    Kentucky         42420  South        Furniture
# ...

# %%
#calculating sales 
df['SALE_PRICE']=df['LIST_PRICE']-df['DISCOUNT']

# %%
#adding new column in dataframe
df
# Out:
#       ORDER_ID ORDER_DATE       SHIP_MODE    SEGMENT        COUNTRY  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  CITY       STATE  POSTALl_CODE REGION         CATEGORY  \
# 0           Henderson    Kentucky         42420  South        Furniture
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDER_ID          9994 non-null   int64
#  1   ORDER_DATE        9994 non-null   datetime64[ns]
#  2   SHIP_MODE         9994 non-null   object
#  3   SEGMENT           9994 non-null   object
#  4   COUNTRY           9994 non-null   object
#  5   CITY              9994 non-null   object
#  6   STATE             9994 non-null   object
#  7   POSTALl_CODE      9994 non-null   int64
#  8   REGION            9994 non-null   object
#  9   CATEGORY          9994 non-null   object
#  10  SUB_CATEGORY      9994 non-null   object
#  11  PRODUCT_ID        9994 non-null   object
#  12  COST_PRICE        9994 non-null   int64
#  13  LIST_PRICE        9994 non-null   int64
#  14  QUANTITY          9994 non-null   int64
#  15  DISCOUNT_PERCENT  9994 non-null   int64
# ...

# %%
#seperating the dataframe from 1 to 9 columns naming df_Order1
df_Order1=df.iloc[:,:9]

# %%
#1 to 9 columns in df_Order1
df_Order1
# Out:
#       ORDER_ID ORDER_DATE       SHIP_MODE    SEGMENT        COUNTRY  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  CITY       STATE  POSTALl_CODE REGION
# 0           Henderson    Kentucky         42420  South
# ...

# %%
#info of df_Order1 table
df_Order1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORDER_ID      9994 non-null   int64
#  1   ORDER_DATE    9994 non-null   datetime64[ns]
#  2   SHIP_MODE     9994 non-null   object
#  3   SEGMENT       9994 non-null   object
#  4   COUNTRY       9994 non-null   object
#  5   CITY          9994 non-null   object
#  6   STATE         9994 non-null   object
#  7   POSTALl_CODE  9994 non-null   int64
#  8   REGION        9994 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 702.8+ KB

# %%
#seperating second dataframe from 10 to19 as df_Order2
df_Order2=df.iloc[:,9:]

# %%
#10 to 19 columns
df_Order2
# Out:
#              CATEGORY SUB_CATEGORY       PRODUCT_ID  COST_PRICE  LIST_PRICE  \
# 0           Furniture    Bookcases  FUR-BO-10001798         240         260
# 1           Furniture       Chairs  FUR-CH-10000454         600         730
# 2     Office Supplies       Labels  OFF-LA-10000240          10          10
# 3           Furniture       Tables  FUR-TA-10000577         780         960
# 4     Office Supplies      Storage  OFF-ST-10000760          20          20
# ...               ...          ...              ...         ...         ...
# 9989        Furniture  Furnishings  FUR-FU-10001889          30          30
# 9990        Furniture  Furnishings  FUR-FU-10000747          70          90
# 9991       Technology       Phones  TEC-PH-10003645         220         260
# 9992  Office Supplies        Paper  OFF-PA-10004041          30          30
# 9993  Office Supplies   Appliances  OFF-AP-10002684         210         240
#
# ...

# %%
#converting df_Oder1 to csv file
df1=df_Order1.to_csv(r"C:\Users\kaladevi\sample\.venv\df_Order1.csv")

# %%
#converting df_Order2 to csv file
df2=df_Order2.to_csv(r"C:\Users\kaladevi\sample\.venv\df_Order2.csv")

# %%
#reading df_csv file as df1
df1=pd.read_csv(r"C:\Users\kaladevi\sample\.venv\df_Order1.csv",index_col=0)

# %%
df1
# Out:
#       ORDER_ID  ORDER_DATE       SHIP_MODE    SEGMENT        COUNTRY  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  CITY       STATE  POSTALl_CODE REGION
# 0           Henderson    Kentucky         42420  South
# ...

# %%
import pandas as pd

# %%
#reading df_Order2 csv file as df2
df2=pd.read_csv(r"C:\Users\kaladevi\sample\.venv\df_Order2.csv",index_col=0)

# %%
df2
# Out:
#              CATEGORY SUB_CATEGORY       PRODUCT_ID  COST_PRICE  LIST_PRICE  \
# 0           Furniture    Bookcases  FUR-BO-10001798         240         260
# 1           Furniture       Chairs  FUR-CH-10000454         600         730
# 2     Office Supplies       Labels  OFF-LA-10000240          10          10
# 3           Furniture       Tables  FUR-TA-10000577         780         960
# 4     Office Supplies      Storage  OFF-ST-10000760          20          20
# ...               ...          ...              ...         ...         ...
# 9989        Furniture  Furnishings  FUR-FU-10001889          30          30
# 9990        Furniture  Furnishings  FUR-FU-10000747          70          90
# 9991       Technology       Phones  TEC-PH-10003645         220         260
# 9992  Office Supplies        Paper  OFF-PA-10004041          30          30
# 9993  Office Supplies   Appliances  OFF-AP-10002684         210         240
#
# ...

# %%
#importing sqlalchemy to insert dataframe csv file in python to sql database
import sqlalchemy

# %%
#to create cursor connection to postgressql
import psycopg2
connection = psycopg2.connect(
    host = "localhost",
    user = "postgres",
    password = "ganesh24"
    
    
)

mediator = connection.cursor()

mediator.execute("select datname from pg_database")
                 
db_names = mediator.fetchall()

# %%
from sqlalchemy import create_engine
import pandas as pd

host = "localhost"
user = "postgres"
password = "ganesh24"
database = "retaildb"

engine = create_engine(f"postgresql://{user}:{password}@{host}/{database}")
dataframe1 = pd.read_csv('C:\\Users\\kaladevi\\sample\\.venv\\df_Order1.csv',index_col=0)
table_name = "dataframe1"
dataframe1.to_sql(table_name,engine,if_exists="replace",index=False)
print("successfully inserted")
# Out:
# successfully inserted

# %%
from sqlalchemy import create_engine
import pandas as pd

host = "localhost"
user = "postgres"
password = "ganesh24"
database = "retaildb"

engine = create_engine(f"postgresql://{user}:{password}@{host}/{database}")
dataframe2 = pd.read_csv('C:\\Users\\kaladevi\\sample\\.venv\\df_Order2.csv',index_col=0)
table_name = "dataframe2"
dataframe2.to_sql(table_name,engine,if_exists="replace",index=False)
print("successfully inserted")
# Out:
# successfully inserted
